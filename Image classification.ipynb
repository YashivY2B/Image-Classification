# %%
import tensorflow as tf

# %%
import numpy as np

# %%
filename = r"C:\Users\G YASHIV\Desktop\ML EL\Images\gettyimages-1214430325.jpg"

# %% [markdown]
# # Method 1 to load image:

# %%
from IPython.display import Image
Image(filename, width=224, height=224)

# %% [markdown]
# # Method 2 to load image:

# %%
from tensorflow.keras.preprocessing import image
img = image.load_img(filename, target_size = (224,224))

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %% [markdown]
# # Method 3 to load image:

# %%
import cv2

# %%
img1=cv2.imread(filename)

# %%
plt.imshow(img1)

# %% [markdown]
# # Method 4 to load image:

# %%
from PIL import Image

# %%
img2=Image.open(filename)

# %%
img2=img2.resize((224,224))

# %%
plt.imshow(img2)

# %% [markdown]
# # Loading the deep learning model:

# %%
mobile=tf.keras.applications.mobilenet_v2.MobileNetV2()

# %%
from tensorflow.keras.preprocessing import image
img = image.load_img(filename, target_size = (224,224))

# %%
plt.imshow(img)

# %%
resized_img=image.img_to_array(img)
final_image=np.expand_dims(resized_img,axis=0)
final_image=tf.keras.applications.mobilenet.preprocess_input(final_image)

# %%
final_image.shape
# Out:
# (1, 224, 224, 3)

# %%
predictions = mobile.predict(final_image)
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
from tensorflow.keras.applications import imagenet_utils

# %%
results=imagenet_utils.decode_predictions(predictions)

# %%
print(results)
# Out:
# [[('n03796401', 'moving_van', 0.29782724), ('n04065272', 'recreational_vehicle', 0.09752981), ('n03977966', 'police_van', 0.051840667), ('n02930766', 'cab', 0.04036389), ('n03769881', 'minibus', 0.04010716)]]
